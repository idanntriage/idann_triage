# %% [markdown]
# # FNN_TE_ATT  Forward Neural Network with an Attention layer
#
# IDANN Model that predicts critical outcomes, with the attention layer.
#
# Interpretability of our FNN model is essential for its adoption by healthcare communities. Therefore we implemented a feature attribution system determined by an entry Attention Layer in our FNN. We were inspired by recent studies on healthcare DNN models like Google, Rajkomar et al. (Jan 2018), and Georgia Tech, Sha et al. (Aug 2017). Keras/Tensorflow didn't have an attention layer ready to use, then we implemented one for our model based on formulas explained at Raffel et al. . The attention layer learns to determine a set of weights that represent the relative importance of each feature on a specific prediction. The resulting model not only became interpretable, but also gained in performance!

# %%
import pandas as pd
import numpy as np
import json 
from sklearn.cross_validation import train_test_split

from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import pickle
import sys 
sys.path.append("../../src/models/train_model")
import NN_VE_model
import attention_layer
sys.path.append("../../src/features")
import build_features, vital_signs_features, age_features, RFV_features, RFV_text_vectorizing

# %matplotlib inline
# Out:
# /home/zenobiosky/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Using TensorFlow backend.

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Model Training

# %%
with open('../../fileConfig.json') as config_file:    
        fileConfig = json.load(config_file)

# %%
reload(NN_VE_model)
NN_VE_model.FNN_TE_ATT_model_training(fileConfig, 'ED_TOTAL_2009_2009.csv')
# Out:
# Creating text for embeddings
# Vocabulary size: 1603
# Average text length: 12.6051971547
# Max text length: 122
# ../../src/models/train_model/attention_layer.py:38: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   context_vector =merge([att_weights, inputs], mode='dot', dot_axes=(1,1), name='context_vector_c'+i)
# /home/zenobiosky/anaconda2/lib/python2.7/site-packages/keras/legacy/layers.py:464: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# AUROC: 85.22%
# AUROC: 85.12%
# AUROC: 84.87%
# AUROC: 87.98%
# AUROC: 87.65%
# AUROC: 86.10%
# AUROC: 87.80%
# AUROC: 86.88%
# AUROC: 85.33%
# AUROC: 83.94%
# ROC AUC: 86.09% (+/- 0.01%)

# %% [markdown]
# ## Model Training, step by step

# %% [markdown]
# ### Reading CDC File

# %%
#reading file
processedDirectory = fileConfig['dataDirectory'] + fileConfig['processedDirectory'] 
cdc_input = pd.read_csv(processedDirectory + 'ED_TOTAL_2009_2009.csv' )

# %% [markdown]
# ### Feature Engineering

# %%
reload(build_features)
predictors, target = build_features.get_features(cdc_input, with_features_for_Embedding=True)
# Out:
# Creating text for embeddings

# %%
list(predictors)
# Out:
# ['Temp_Baseline',
#  'Pulse_Baseline',
#  'Sys_BP_Baseline',
#  'Resp_Rate_Baseline',
#  'Oxygen_Sat_Baseline',
#  'Reason_Chest_Pain',
#  'Reason_Abdominal_Pain',
#  'Reason_Headache',
#  'Reason_Shortness_of_Breath',
#  'Reason_Back_Pain',
#  'Reason_Cough',
#  'Reason_Nausea_Vomiting',
#  'Reason_Fever_Chills',
#  'Reason_Syncope',
#  'Reason_Dizziness',
#  'Reason_Psychiatric_Complaint',
#  'Reason_Nervous_System',
#  'Reason_Cardiovascular_Other',
#  'Reason_Ears_Eyes_Complaint',
#  'Reason_Respiratory_Other',
#  'Reason_Gastrointestinal_Other',
#  'Reason_Genitourinary_Other',
#  'Reason_Skin_Hair_Nails_Complaint',
#  'Reason_Musculoskeletal_Other',
#  'Reason_Injury_Poisoning',
#  'Reason_Other',
#  'Hypothermia',
#  'Hyperthermia',
#  'Bradycardia',
#  'Mild_Tachycardia',
#  'Moderate_Tachycardia',
#  'Severe_Tachycardia',
#  'Hypotension',
#  'Hypertension',
#  'Bradypnea',
#  'Moderate_Tachypnea',
#  'Severe_Tachypnea',
#  'Mild_Hypoxia',
#  'Severe_Hypoxia',
#  'Age_18_30',
#  'Age_31_40',
#  'Age_41_50',
#  'Age_51_60',
#  'Age_61_70',
#  'Age_71_80',
#  'Age_81_Above',
#  'Male_Flag',
#  'Female_Flag',
#  'Ambulance_Arrival',
#  'Other_Arrival',
#  'Unknown_Arrival',
#  'ARREMS',
#  'AGE',
#  'SEX',
#  'RFV1',
#  'RFV2',
#  'RFV3',
#  'RFV1_text',
#  'RFV2_text',
#  'RFV3_text',
#  'MSA',
#  'DIABETES',
#  'CHF']

# %% [markdown]
# ### Vectorizing text for Embeddings

# %%
# append all RFVn_text  into one text
# vectorize, get a number_id for each word (tokenizer has the dictionary)
# make each rfv_data_vectorized the same length, appending zeroes
# returns MAC_VOCAB: length of the dictionary, max_seq_length: maximum text length 
predictors, max_text_length, MAX_VOCAB,  tokenizer = \
                     RFV_text_vectorizing.vectorize_RFV_text (predictors,  debug=False)
# Out:
# Vocabulary size: 1603
# Average text length: 12.6051971547
# Max text length: 122

# %%
with open("../../models/cdc_2009_att_text_tokenizer.pickle", "wb") as f:
    pickle.dump(tokenizer, f)
with open("../../models/cdc_2009_att_text_max_length.pickle", "wb") as f:
    pickle.dump(max_text_length, f)

# %%
list(predictors)
# Out:
# ['Temp_Baseline',
#  'Pulse_Baseline',
#  'Sys_BP_Baseline',
#  'Resp_Rate_Baseline',
#  'Oxygen_Sat_Baseline',
#  'Reason_Chest_Pain',
#  'Reason_Abdominal_Pain',
#  'Reason_Headache',
#  'Reason_Shortness_of_Breath',
#  'Reason_Back_Pain',
#  'Reason_Cough',
#  'Reason_Nausea_Vomiting',
#  'Reason_Fever_Chills',
#  'Reason_Syncope',
#  'Reason_Dizziness',
#  'Reason_Psychiatric_Complaint',
#  'Reason_Nervous_System',
#  'Reason_Cardiovascular_Other',
#  'Reason_Ears_Eyes_Complaint',
#  'Reason_Respiratory_Other',
#  'Reason_Gastrointestinal_Other',
#  'Reason_Genitourinary_Other',
#  'Reason_Skin_Hair_Nails_Complaint',
#  'Reason_Musculoskeletal_Other',
#  'Reason_Injury_Poisoning',
#  'Reason_Other',
#  'Hypothermia',
#  'Hyperthermia',
#  'Bradycardia',
#  'Mild_Tachycardia',
#  'Moderate_Tachycardia',
#  'Severe_Tachycardia',
#  'Hypotension',
#  'Hypertension',
#  'Bradypnea',
#  'Moderate_Tachypnea',
#  'Severe_Tachypnea',
#  'Mild_Hypoxia',
#  'Severe_Hypoxia',
#  'Age_18_30',
#  'Age_31_40',
#  'Age_41_50',
#  'Age_51_60',
#  'Age_61_70',
#  'Age_71_80',
#  'Age_81_Above',
#  'Male_Flag',
#  'Female_Flag',
#  'Ambulance_Arrival',
#  'Other_Arrival',
#  'Unknown_Arrival',
#  'ARREMS',
#  'AGE',
#  'SEX',
#  'RFV1',
#  'RFV2',
#  'RFV3',
#  'MSA',
#  'DIABETES',
#  'CHF',
#  'RFV_data']

# %% [markdown]
# ## NN model

# %%
reload(NN_VE_model)
reload(attention_layer)
nn_model = NN_VE_model.create_model(l2=0.0001, n_units =100, apply_attention=True,
                                    embedding_nh=100, 
                                    input_text_length=max_text_length,
                                    vocab_size=MAX_VOCAB)
nn_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_70 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_71 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_72 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_62 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 1, 100)       400         input_70[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 1, 100)       300         input_71[0][0]
# __________________________________________________________________________________________________
# input_63 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 1, 100)       300         input_72[0][0]
# __________________________________________________________________________________________________
# input_64 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_69 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_65 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_66 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_67 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_68 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_76 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_77 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_78 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_79 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_80 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_81 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_82 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_83 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_84 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_85 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_86 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_87 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_88 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_89 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_90 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_91 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_92 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_93 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_94 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_95 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_96 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_97 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_98 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_99 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_100 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_101 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_102 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_103 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_104 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_105 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_106 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_107 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_108 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_109 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_110 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_111 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_112 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_113 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_114 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_115 (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# input_73 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_74 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# input_75 (InputLayer)           (None, 5)            0
# __________________________________________________________________________________________________
# sex_indicator (Dense)           (None, 100)          200         input_62[0][0]
# __________________________________________________________________________________________________
# arrival_model (Reshape)         (None, 100)          0           embedding_4[0][0]
# __________________________________________________________________________________________________
# msa_indicator (Reshape)         (None, 100)          0           embedding_5[0][0]
# __________________________________________________________________________________________________
# chf_indicator (Dense)           (None, 100)          200         input_63[0][0]
# __________________________________________________________________________________________________
# diabetes_indicator (Reshape)    (None, 100)          0           embedding_6[0][0]
# __________________________________________________________________________________________________
# Age (Dense)                     (None, 100)          200         input_64[0][0]
# __________________________________________________________________________________________________
# Temperature (Dense)             (None, 100)          200         input_69[0][0]
# __________________________________________________________________________________________________
# Pulse_Heart_rate (Dense)        (None, 100)          200         input_65[0][0]
# __________________________________________________________________________________________________
# Systolic_blood_pressure (Dense) (None, 100)          200         input_66[0][0]
# __________________________________________________________________________________________________
# Respiratory_rate (Dense)        (None, 100)          200         input_67[0][0]
# __________________________________________________________________________________________________
# Oxygen_Saturation (Dense)       (None, 100)          200         input_68[0][0]
# __________________________________________________________________________________________________
# Hypothermia (Dense)             (None, 100)          200         input_76[0][0]
# __________________________________________________________________________________________________
# Hyperthermia (Dense)            (None, 100)          200         input_77[0][0]
# __________________________________________________________________________________________________
# Bradycardia (Dense)             (None, 100)          200         input_78[0][0]
# __________________________________________________________________________________________________
# Mild_Tachycardia (Dense)        (None, 100)          200         input_79[0][0]
# __________________________________________________________________________________________________
# Moderate_Tachycardia (Dense)    (None, 100)          200         input_80[0][0]
# __________________________________________________________________________________________________
# Severe_Tachycardia (Dense)      (None, 100)          200         input_81[0][0]
# __________________________________________________________________________________________________
# Hypotension (Dense)             (None, 100)          200         input_82[0][0]
# __________________________________________________________________________________________________
# Hypertension (Dense)            (None, 100)          200         input_83[0][0]
# __________________________________________________________________________________________________
# Bradypnea (Dense)               (None, 100)          200         input_84[0][0]
# __________________________________________________________________________________________________
# Moderate_Tachypnea (Dense)      (None, 100)          200         input_85[0][0]
# __________________________________________________________________________________________________
# Severe_Tachypnea (Dense)        (None, 100)          200         input_86[0][0]
# __________________________________________________________________________________________________
# Mild_Hypoxia (Dense)            (None, 100)          200         input_87[0][0]
# __________________________________________________________________________________________________
# Severe_Hypoxia (Dense)          (None, 100)          200         input_88[0][0]
# __________________________________________________________________________________________________
# Reason_Chest_Pain (Dense)       (None, 100)          200         input_89[0][0]
# __________________________________________________________________________________________________
# Reason_Abdominal_Pain (Dense)   (None, 100)          200         input_90[0][0]
# __________________________________________________________________________________________________
# Reason_Headache (Dense)         (None, 100)          200         input_91[0][0]
# __________________________________________________________________________________________________
# Reason_Shortness_of_Breath (Den (None, 100)          200         input_92[0][0]
# __________________________________________________________________________________________________
# Reason_Cough (Dense)            (None, 100)          200         input_93[0][0]
# __________________________________________________________________________________________________
# Reason_Nausea_Vomiting (Dense)  (None, 100)          200         input_94[0][0]
# __________________________________________________________________________________________________
# Reason_Fever_Chills (Dense)     (None, 100)          200         input_95[0][0]
# __________________________________________________________________________________________________
# Reason_Syncope (Dense)          (None, 100)          200         input_96[0][0]
# __________________________________________________________________________________________________
# Reason_Dizziness (Dense)        (None, 100)          200         input_97[0][0]
# __________________________________________________________________________________________________
# Reason_Psychiatric_Complaint (D (None, 100)          200         input_98[0][0]
# __________________________________________________________________________________________________
# Reason_Nervous_System (Dense)   (None, 100)          200         input_99[0][0]
# __________________________________________________________________________________________________
# Reason_Cardiovascular_Other (De (None, 100)          200         input_100[0][0]
# __________________________________________________________________________________________________
# Reason_Ears_Eyes_Complaint (Den (None, 100)          200         input_101[0][0]
# __________________________________________________________________________________________________
# Reason_Respiratory_Other (Dense (None, 100)          200         input_102[0][0]
# __________________________________________________________________________________________________
# Reason_Gastrointestinal_Other ( (None, 100)          200         input_103[0][0]
# __________________________________________________________________________________________________
# Reason_Genitourinary_Other (Den (None, 100)          200         input_104[0][0]
# __________________________________________________________________________________________________
# Reason_Skin_Hair_Nails_Complain (None, 100)          200         input_105[0][0]
# __________________________________________________________________________________________________
# Reason_Musculoskeletal_Other (D (None, 100)          200         input_106[0][0]
# __________________________________________________________________________________________________
# Reason_Injury_Poisoning (Dense) (None, 100)          200         input_107[0][0]
# __________________________________________________________________________________________________
# Reason_Other (Dense)            (None, 100)          200         input_108[0][0]
# __________________________________________________________________________________________________
# Age_18_30_range (Dense)         (None, 100)          200         input_109[0][0]
# __________________________________________________________________________________________________
# Age_31_40_range (Dense)         (None, 100)          200         input_110[0][0]
# __________________________________________________________________________________________________
# Age_41_50_range (Dense)         (None, 100)          200         input_111[0][0]
# __________________________________________________________________________________________________
# Age_51_60_range (Dense)         (None, 100)          200         input_112[0][0]
# __________________________________________________________________________________________________
# Age_61_70_range (Dense)         (None, 100)          200         input_113[0][0]
# __________________________________________________________________________________________________
# Age_71_80_range (Dense)         (None, 100)          200         input_114[0][0]
# __________________________________________________________________________________________________
# Age_81_Above (Dense)            (None, 100)          200         input_115[0][0]
# __________________________________________________________________________________________________
# reason1_for_visit (Dense)       (None, 100)          600         input_73[0][0]
# __________________________________________________________________________________________________
# reason2_for_visit (Dense)       (None, 100)          600         input_74[0][0]
# __________________________________________________________________________________________________
# reason3_for_visit (Dense)       (None, 100)          600         input_75[0][0]
# __________________________________________________________________________________________________
# rfv_text_data_input (InputLayer (None, 122)          0
# __________________________________________________________________________________________________
# input_features (Lambda)         (None, 54, 100)      0           sex_indicator[0][0]
#                                                                  arrival_model[0][0]
#                                                                  msa_indicator[0][0]
#                                                                  chf_indicator[0][0]
#                                                                  diabetes_indicator[0][0]
#                                                                  Age[0][0]
#                                                                  Temperature[0][0]
#                                                                  Pulse_Heart_rate[0][0]
#                                                                  Systolic_blood_pressure[0][0]
#                                                                  Respiratory_rate[0][0]
#                                                                  Oxygen_Saturation[0][0]
#                                                                  Hypothermia[0][0]
#                                                                  Hyperthermia[0][0]
#                                                                  Bradycardia[0][0]
#                                                                  Mild_Tachycardia[0][0]
#                                                                  Moderate_Tachycardia[0][0]
#                                                                  Severe_Tachycardia[0][0]
#                                                                  Hypotension[0][0]
#                                                                  Hypertension[0][0]
#                                                                  Bradypnea[0][0]
#                                                                  Moderate_Tachypnea[0][0]
#                                                                  Severe_Tachypnea[0][0]
#                                                                  Mild_Hypoxia[0][0]
#                                                                  Severe_Hypoxia[0][0]
#                                                                  Reason_Chest_Pain[0][0]
#                                                                  Reason_Abdominal_Pain[0][0]
#                                                                  Reason_Headache[0][0]
#                                                                  Reason_Shortness_of_Breath[0][0]
#                                                                  Reason_Cough[0][0]
#                                                                  Reason_Nausea_Vomiting[0][0]
#                                                                  Reason_Fever_Chills[0][0]
#                                                                  Reason_Syncope[0][0]
#                                                                  Reason_Dizziness[0][0]
#                                                                  Reason_Psychiatric_Complaint[0][0
#                                                                  Reason_Nervous_System[0][0]
#                                                                  Reason_Cardiovascular_Other[0][0]
#                                                                  Reason_Ears_Eyes_Complaint[0][0]
#                                                                  Reason_Respiratory_Other[0][0]
#                                                                  Reason_Gastrointestinal_Other[0][
#                                                                  Reason_Genitourinary_Other[0][0]
#                                                                  Reason_Skin_Hair_Nails_Complaint[
#                                                                  Reason_Musculoskeletal_Other[0][0
#                                                                  Reason_Injury_Poisoning[0][0]
#                                                                  Reason_Other[0][0]
#                                                                  Age_18_30_range[0][0]
#                                                                  Age_31_40_range[0][0]
#                                                                  Age_41_50_range[0][0]
#                                                                  Age_51_60_range[0][0]
#                                                                  Age_61_70_range[0][0]
#                                                                  Age_71_80_range[0][0]
#                                                                  Age_81_Above[0][0]
#                                                                  reason1_for_visit[0][0]
#                                                                  reason2_for_visit[0][0]
#                                                                  reason3_for_visit[0][0]
# __________________________________________________________________________________________________
# rfv_text_embeddings (Embedding) (None, 122, 100)     160400      rfv_text_data_input[0][0]
# __________________________________________________________________________________________________
# input_features_with_text (Conca (None, 176, 100)     0           input_features[0][0]
#                                                                  rfv_text_embeddings[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 176, 1)       101         input_features_with_text[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 176)          0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# attention_weights1 (Activation) (None, 176)          0           reshape_2[0][0]
# __________________________________________________________________________________________________
# context_vector_c1 (Merge)       (None, 100)          0           attention_weights1[0][0]
#                                                                  input_features_with_text[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          10100       context_vector_c1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          10100       dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            101         dense_6[0][0]
# ==================================================================================================
# Total params: 193,202
# Trainable params: 193,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
reload(NN_VE_model)
X_train, X_dev, y_train, y_dev = train_test_split(predictors, target, test_size = 0.1)
X_train_list = NN_VE_model.get_x_list(X_train)
X_dev_list = NN_VE_model.get_x_list(X_dev)

# %%
reload(NN_VE_model)
reload(attention_layer)
roc_auc, cdc_model = NN_VE_model.train_model(X_train_list, y_train,X_dev_list, y_dev, 
                                  num_epochs=40, l2=0.0001, n_units=50, 
                                apply_attention= True, embedding_nh=50, n_layers =3,att_l2=0.0001,
                                input_text_length=max_text_length,  vocab_size=MAX_VOCAB,  verbose = True )
# Out:
# Train on 21888 samples, validate on 2433 samples
# Epoch 1/40
# 21888/21888 [==============================] - 13s 594us/step - loss: 0.7429 - acc: 0.6552 - val_loss: 0.7384 - val_acc: 0.0727
# Epoch 2/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.6847 - acc: 0.7256 - val_loss: 0.4612 - val_acc: 0.9162
# Epoch 3/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.5704 - acc: 0.7418 - val_loss: 0.5068 - val_acc: 0.7768
# Epoch 4/40
# 21888/21888 [==============================] - 3s 135us/step - loss: 0.5078 - acc: 0.7664 - val_loss: 0.4508 - val_acc: 0.8105
# Epoch 5/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.5018 - acc: 0.7633 - val_loss: 0.3480 - val_acc: 0.8607
# Epoch 6/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4963 - acc: 0.7678 - val_loss: 0.5175 - val_acc: 0.7608
# Epoch 7/40
# 21888/21888 [==============================] - 3s 140us/step - loss: 0.4912 - acc: 0.7573 - val_loss: 0.3267 - val_acc: 0.8640
# Epoch 8/40
# 21888/21888 [==============================] - 3s 150us/step - loss: 0.4913 - acc: 0.7652 - val_loss: 0.3981 - val_acc: 0.8229
# Epoch 9/40
# 21888/21888 [==============================] - 3s 141us/step - loss: 0.4824 - acc: 0.7680 - val_loss: 0.7073 - val_acc: 0.6321
# Epoch 10/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.4883 - acc: 0.7557 - val_loss: 0.4378 - val_acc: 0.8031
# Epoch 11/40
# 21888/21888 [==============================] - 3s 132us/step - loss: 0.4818 - acc: 0.7651 - val_loss: 0.4232 - val_acc: 0.8072
# Epoch 12/40
# 21888/21888 [==============================] - 3s 137us/step - loss: 0.4852 - acc: 0.7587 - val_loss: 0.5453 - val_acc: 0.7312
# Epoch 13/40
# 21888/21888 [==============================] - 3s 135us/step - loss: 0.4782 - acc: 0.7599 - val_loss: 0.5039 - val_acc: 0.7583
# Epoch 14/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4839 - acc: 0.7526 - val_loss: 0.3938 - val_acc: 0.8192
# Epoch 15/40
# 21888/21888 [==============================] - 3s 132us/step - loss: 0.4773 - acc: 0.7593 - val_loss: 0.3671 - val_acc: 0.8339
# Epoch 16/40
# 21888/21888 [==============================] - 3s 132us/step - loss: 0.4746 - acc: 0.7670 - val_loss: 0.7402 - val_acc: 0.5984
# Epoch 17/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4772 - acc: 0.7514 - val_loss: 0.5098 - val_acc: 0.7460
# Epoch 18/40
# 21888/21888 [==============================] - 3s 137us/step - loss: 0.4741 - acc: 0.7542 - val_loss: 0.4740 - val_acc: 0.7690
# Epoch 19/40
# 21888/21888 [==============================] - 3s 137us/step - loss: 0.4798 - acc: 0.7518 - val_loss: 0.5728 - val_acc: 0.7053
# Epoch 20/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4718 - acc: 0.7544 - val_loss: 0.3641 - val_acc: 0.8335
# Epoch 21/40
# 21888/21888 [==============================] - 3s 132us/step - loss: 0.4787 - acc: 0.7541 - val_loss: 0.4066 - val_acc: 0.8068
# Epoch 22/40
# 21888/21888 [==============================] - 3s 136us/step - loss: 0.4755 - acc: 0.7547 - val_loss: 0.3932 - val_acc: 0.8134
# Epoch 23/40
# 21888/21888 [==============================] - 3s 135us/step - loss: 0.4712 - acc: 0.7580 - val_loss: 0.5123 - val_acc: 0.7452
# Epoch 24/40
# 21888/21888 [==============================] - 3s 136us/step - loss: 0.4740 - acc: 0.7543 - val_loss: 0.3752 - val_acc: 0.8257
# Epoch 25/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.4732 - acc: 0.7517 - val_loss: 0.3951 - val_acc: 0.8187
# Epoch 26/40
# 21888/21888 [==============================] - 3s 132us/step - loss: 0.4691 - acc: 0.7590 - val_loss: 0.3495 - val_acc: 0.8426
# Epoch 27/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4716 - acc: 0.7577 - val_loss: 0.6085 - val_acc: 0.6737
# Epoch 28/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.4716 - acc: 0.7536 - val_loss: 0.6731 - val_acc: 0.6264
# Epoch 29/40
# 21888/21888 [==============================] - 3s 136us/step - loss: 0.4751 - acc: 0.7475 - val_loss: 0.5010 - val_acc: 0.7485
# Epoch 30/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.4708 - acc: 0.7563 - val_loss: 0.3932 - val_acc: 0.8146
# Epoch 31/40
# 21888/21888 [==============================] - 3s 136us/step - loss: 0.4679 - acc: 0.7553 - val_loss: 0.4216 - val_acc: 0.7941
# Epoch 32/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4655 - acc: 0.7546 - val_loss: 0.5182 - val_acc: 0.7460
# Epoch 33/40
# 21888/21888 [==============================] - 3s 137us/step - loss: 0.4643 - acc: 0.7605 - val_loss: 0.4759 - val_acc: 0.7596
# Epoch 34/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.4685 - acc: 0.7488 - val_loss: 0.4527 - val_acc: 0.7752
# Epoch 35/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.4710 - acc: 0.7548 - val_loss: 0.4925 - val_acc: 0.7546
# Epoch 36/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4686 - acc: 0.7544 - val_loss: 0.4018 - val_acc: 0.8035
# Epoch 37/40
# 21888/21888 [==============================] - 3s 133us/step - loss: 0.4661 - acc: 0.7561 - val_loss: 0.4122 - val_acc: 0.7982
# Epoch 38/40
# 21888/21888 [==============================] - 3s 134us/step - loss: 0.4644 - acc: 0.7589 - val_loss: 0.7117 - val_acc: 0.6091
# Epoch 39/40
# 21888/21888 [==============================] - 3s 136us/step - loss: 0.4640 - acc: 0.7561 - val_loss: 0.4642 - val_acc: 0.7707
# Epoch 40/40
# 21888/21888 [==============================] - 3s 135us/step - loss: 0.4637 - acc: 0.7614 - val_loss: 0.4115 - val_acc: 0.7970
# AUROC: 84.88%

# %%
reload(NN_VE_model)
reload(attention_layer)
roc_auc, cdc_model = NN_VE_model.train_model(X_train_list, y_train,X_dev_list, y_dev, 
                                  num_epochs=40, l2=0.0001, n_units=50, 
                                apply_attention= True, embedding_nh=50, n_layers =3,att_l2=0.0001,
                                input_text_length=max_text_length,  vocab_size=MAX_VOCAB,  verbose = False )
# Out:
# AUROC: 87.81%

# %% [markdown]
# ## Cross Validation

# %%
reload(NN_VE_model)
NN_VE_model.cross_Validation (40, predictors, target,l2=0.0001,units_n = 50,apply_attention= True,
                              embedding_nh=50,   n_layers =3, att_l2=0.0001,
                             input_text_length=max_text_length,  vocab_size=MAX_VOCAB)
# Out:
# AUROC: 85.24%
# AUROC: 85.05%
# AUROC: 84.91%
# AUROC: 88.07%
# AUROC: 87.63%
# AUROC: 86.14%
# AUROC: 87.64%
# AUROC: 86.76%
# AUROC: 85.40%
# AUROC: 83.94%
# ROC AUC: 86.08% (+/- 0.01%)

# %% [markdown]
# ## Train Model with all data
#
# This is the model that got the highest ROC AUC (using 10 fold cross validation), therefore we will use it for prediction. We will now train this model with all data we have, and that is the model that will be use for prediction with the test data and in the API service.
# References:
# https://stats.stackexchange.com/questions/2306/feature-selection-for-final-model-when-performing-cross-validation-in-machine
# https://machinelearningmastery.com/train-final-machine-learning-model/

# %%
X_train_list = NN_VE_model.get_x_list(predictors)

# %%
reload(NN_VE_model)
cdc_model = NN_VE_model.train_full_model(X_train_list, target, 
                                  num_epochs=40, l2=0.0001, n_units=50, 
                                apply_attention= True, embedding_nh=50, n_layers =3,att_l2=0.0001,
                                input_text_length=max_text_length,  vocab_size=MAX_VOCAB,  verbose = True )
# Out:
# Epoch 1/40
# 24321/24321 [==============================] - 12s 479us/step - loss: 0.7415 - acc: 0.3843
# Epoch 2/40
# 24321/24321 [==============================] - 3s 128us/step - loss: 0.6882 - acc: 0.6758
# Epoch 3/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.5720 - acc: 0.7307
# Epoch 4/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.5142 - acc: 0.7650
# Epoch 5/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.5098 - acc: 0.7607
# Epoch 6/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.4926 - acc: 0.7718
# Epoch 7/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.4990 - acc: 0.7663
# Epoch 8/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4949 - acc: 0.7630
# Epoch 9/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4898 - acc: 0.7641
# Epoch 10/40
# 24321/24321 [==============================] - 3s 124us/step - loss: 0.4891 - acc: 0.7614
# Epoch 11/40
# 24321/24321 [==============================] - 3s 128us/step - loss: 0.4858 - acc: 0.7634
# Epoch 12/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4895 - acc: 0.7556
# Epoch 13/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4828 - acc: 0.7570
# Epoch 14/40
# 24321/24321 [==============================] - 3s 138us/step - loss: 0.4843 - acc: 0.7566
# Epoch 15/40
# 24321/24321 [==============================] - 3s 140us/step - loss: 0.4816 - acc: 0.7542
# Epoch 16/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.4810 - acc: 0.7512
# Epoch 17/40
# 24321/24321 [==============================] - 3s 126us/step - loss: 0.4838 - acc: 0.7516
# Epoch 18/40
# 24321/24321 [==============================] - 3s 123us/step - loss: 0.4804 - acc: 0.7528
# Epoch 19/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4814 - acc: 0.7508
# Epoch 20/40
# 24321/24321 [==============================] - 3s 124us/step - loss: 0.4818 - acc: 0.7493
# Epoch 21/40
# 24321/24321 [==============================] - 3s 126us/step - loss: 0.4800 - acc: 0.7503
# Epoch 22/40
# 24321/24321 [==============================] - 3s 123us/step - loss: 0.4781 - acc: 0.7531
# Epoch 23/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4789 - acc: 0.7549
# Epoch 24/40
# 24321/24321 [==============================] - 3s 122us/step - loss: 0.4792 - acc: 0.7496
# Epoch 25/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4765 - acc: 0.7490
# Epoch 26/40
# 24321/24321 [==============================] - 3s 126us/step - loss: 0.4792 - acc: 0.7538
# Epoch 27/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.4786 - acc: 0.7477
# Epoch 28/40
# 24321/24321 [==============================] - 3s 129us/step - loss: 0.4760 - acc: 0.7531
# Epoch 29/40
# 24321/24321 [==============================] - 3s 129us/step - loss: 0.4752 - acc: 0.7555
# Epoch 30/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4787 - acc: 0.7514
# Epoch 31/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4744 - acc: 0.7538
# Epoch 32/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4737 - acc: 0.7511
# Epoch 33/40
# 24321/24321 [==============================] - 3s 124us/step - loss: 0.4704 - acc: 0.7560
# Epoch 34/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4702 - acc: 0.7559
# Epoch 35/40
# 24321/24321 [==============================] - 3s 123us/step - loss: 0.4702 - acc: 0.7541
# Epoch 36/40
# 24321/24321 [==============================] - 3s 127us/step - loss: 0.4666 - acc: 0.7585
# Epoch 37/40
# 24321/24321 [==============================] - 3s 129us/step - loss: 0.4696 - acc: 0.7549
# Epoch 38/40
# 24321/24321 [==============================] - 3s 125us/step - loss: 0.4707 - acc: 0.7551
# Epoch 39/40
# 24321/24321 [==============================] - 3s 126us/step - loss: 0.4708 - acc: 0.7533
# Epoch 40/40
# 24321/24321 [==============================] - 3s 123us/step - loss: 0.4692 - acc: 0.7556

# %%
cdc_model.save ('../../models/cdc_2009_nn_att_text_embedding.H5') 
# for w210 results AUC ROC  87.98%

# %% [markdown]
# ### Appendix: Other hyper-parameter values

# %% [markdown]
# ```
# NN_VE_model.cross_Validation (20, predictors, target,l2=0.0001,units_n = 50,apply_attention= True,
#                               embedding_nh=50,   n_layers =3, att_l2=0.0001,
#                              input_text_length=max_text_length,  vocab_size=MAX_VOCAB)
# AUROC: 84.76%
# AUROC: 84.43%
# AUROC: 84.56%
# AUROC: 88.17%
# AUROC: 87.41%
# AUROC: 85.60%
# AUROC: 87.24%
# AUROC: 86.49%
# AUROC: 85.12%
# AUROC: 83.62%
# ROC AUC: 85.74% (+/- 0.01%)
# ```

# %% [markdown]
# ```
# NN_VE_model.cross_Validation (50, predictors, target,l2=0.0001,units_n = 50,apply_attention= True,
#                               embedding_nh=50,   n_layers =3, att_l2=0.0001,
#                              input_text_length=max_seq_length,  vocab_size=MAX_VOCAB)
# AUROC: 85.00%
#
# ```

# %% [markdown]
# ```
# reload(NN_VE_model)
# NN_VE_model.cross_Validation (10, predictors, target,l2=0.0001,units_n = 50,apply_attention= True,
#                               embedding_nh=50,   n_layers =3, att_l2=0.0001,
#                              input_text_length=max_seq_length,  vocab_size=MAX_VOCAB)
#                              AUROC: 84.57%
# AUROC: 84.02%
# AUROC: 84.27%
# AUROC: 88.04%
# AUROC: 86.91%
# AUROC: 85.35%
# AUROC: 87.14%
# AUROC: 86.55%
# AUROC: 85.22%
# AUROC: 83.15%
# ROC AUC: 85.52% (+/- 0.01%)
# ```

# %% [markdown]
# ```
# reload(NN_VE_model)
# NN_VE_model.cross_Validation (10, predictors, target,l2=0.0001,units_n = 50,apply_attention= True,
#                               embedding_nh=50,   n_layers =2, att_l2=0.0001,
#                              input_text_length=max_seq_length,  vocab_size=MAX_VOCAB)
# AUROC: 84.36%
# AUROC: 83.93%
# AUROC: 84.34%
# AUROC: 88.18%
# AUROC: 87.14%
# AUROC: 85.17%
# AUROC: 87.09%
# AUROC: 86.18%
# AUROC: 85.22%
# AUROC: 83.19%
# ROC AUC: 85.48% (+/- 0.02%)
# ```

# %% [markdown]
# ```
# reload(NN_VE_model)
# NN_VE_model.cross_Validation (5, predictors, target,l2=0.0001,units_n = 50,apply_attention= True,
#                               embedding_nh=100,   n_layers =2, att_l2=0.0001,
#                              input_text_length=max_seq_length,  vocab_size=MAX_VOCAB)
#
# AUROC: 84.17%
# AUROC: 83.45%
# AUROC: 83.74%
# AUROC: 88.00%
# AUROC: 86.77%
# AUROC: 84.79%
# AUROC: 86.78%
# AUROC: 85.67%
# AUROC: 85.17%
# AUROC: 82.16%
# ROC AUC: 85.07% (+/- 0.02%)
# ```
